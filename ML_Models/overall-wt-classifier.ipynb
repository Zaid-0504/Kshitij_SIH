# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import joblib
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from wordcloud import WordCloud
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, BaggingClassifier
import warnings
warnings.simplefilter('ignore')
sns.set_theme(style="dark")
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# Utility Functions
def remove_outliers(df, feature):
    """
    Remove Outliers using IRQ method
    
    df: dataframe
    feature: dataframe column"""
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 1.5 * iqr
    lower_bound = q1 - 1.5 * iqr
    df = df[(df[feature] >= lower_bound) & (df[feature] <= upper_bound)]
    return df

def histogram_boxplot(data, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (15,10))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  
        sharex=True,  
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    ) 
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    ) 
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  

def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 2, 6))
    else:
        plt.figure(figsize=(n + 2, 6))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n],
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  
        else:
            label = p.get_height() 

        x = p.get_x() + p.get_width() / 2  
        y = p.get_height()

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        ) 

    plt.show() 

def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 5, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

def distribution_plot_wrt_target(data, predictor, target):
    """
    Print the distribution plot

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
        stat="density",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[2]))
    sns.histplot(
        data=data[data[target] == target_uniq[2]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
        stat="density",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

def checking_overfitting_undefitting(y_train, y_train_pred, y_test, y_test_pred):
    """
    Print whether the model is underfit, overfit or good fit.
    
    y_train = training data
    y_train_pred = predictions on training data
    y_test = testing data
    y_test_pred = predictions on testing data
    """
    training_accuracy = accuracy_score(y_train, y_train_pred)
    testing_accuracy = accuracy_score(y_test, y_test_pred)
    if training_accuracy<=0.65:
        print("Model is underfitting.") 
    elif training_accuracy>0.65 and abs(training_accuracy-testing_accuracy)>0.15:
        print("Model is overfitting.")
    else:
        print("Model is not underfitting/overfitting.")

def calculate_classification_metrics(y_true, y_pred, algorithm):
    """
    Return the classification Metrics
    
    y_true = actual values
    y_pred = predicted values
    y_pred_probability = probability values
    algorithm = algorithm name
    """
    accuracy = round(accuracy_score(y_true, y_pred), 3)
    precision = round(precision_score(y_true, y_pred, average='weighted'), 3)
    recall = round(recall_score(y_true, y_pred, average='weighted'), 3)
    f1 = round(f1_score(y_true, y_pred, average='weighted'), 3)
    print("Algorithm: ", algorithm)
    print()
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print()
    cm = confusion_matrix(y_true, y_pred)
    labels = ['Overcast', 'Clear','Foggy']
    plt.figure(figsize=(10, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    return accuracy, precision, recall, f1

# Callback function to avoid overfitting
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy')>0.90) and (logs.get('accuracy')>0.95):
            print("\nValidation and training accuracies are high so cancelling training!")
            self.model.stop_training = True

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Data Inspection

# %%
# Fetching data
data = pd.read_csv("/kaggle/input/weather-dataset/weatherHistory.csv")
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
# Analyzing the Data types and Exploring the number of entities in a feature
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
# Checking Statistical Summary
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
# Checking Target Variable
print(data["Summary"].value_counts())
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# Windy                                      8
# Humid and Overcast                         7
# Windy and Foggy                            4
# Windy and Dry                              1
# Dangerously Windy and Partly Cloudy        1
# Breezy and Dry                             1
# Name: Summary, dtype: int64

# %%
# Reduced Data (Using only 3 classes)
data = data[(data["Summary"] == "Overcast") | (data["Summary"] == "Clear") | (data["Summary"] == "Foggy")]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34635 entries, 46 to 96436
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            34635 non-null  object
#  1   Summary                   34635 non-null  object
#  2   Precip Type               34396 non-null  object
#  3   Temperature (C)           34635 non-null  float64
#  4   Apparent Temperature (C)  34635 non-null  float64
#  5   Humidity                  34635 non-null  float64
#  6   Wind Speed (km/h)         34635 non-null  float64
#  7   Wind Bearing (degrees)    34635 non-null  float64
#  8   Visibility (km)           34635 non-null  float64
#  9   Loud Cover                34635 non-null  float64
#  10  Pressure (millibars)      34635 non-null  float64
#  11  Daily Summary             34635 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Data Cleaning

# %% [markdown]
# * #### Missing Values Treatment

# %%
# Calculating Missing Values
missing_values_count = data.isnull().sum()
missing_values_count
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 239
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# Since 359 is a reasonable count. Dropping the respective rows. If the count were smaller we would've filled it up with dummy values
data.dropna(inplace=True) 
# Again checking for values
missing_values_count = data.isnull().sum()
missing_values_count
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# * #### Duplicated Values Treatment

# %%
# Calculating number of duplicated values
print("Duplicated Values: ",data.duplicated().sum())
# Out:
# Duplicated Values:  17

# %%
# Removing duplicated values
data.drop_duplicates(inplace=True)
# Again checking for duplicated values
print("Duplicated Values: ", data.duplicated().sum())
# Out:
# Duplicated Values:  0

# %% [markdown]
# * #### Data Formatting

# %%
# Rounding up the float64 data upto 2 decimals.
float_cols = data.select_dtypes(include='float')
data[float_cols.columns] = float_cols.round(2)
data.head()
# Out:
#                    Formatted Date   Summary Precip Type  Temperature (C)  \
# 46  2006-04-10 22:00:00.000 +0200  Overcast        rain            14.42
# 47  2006-04-10 23:00:00.000 +0200  Overcast        rain            14.26
# 48  2006-04-11 00:00:00.000 +0200  Overcast        rain            13.77
# 49  2006-04-11 01:00:00.000 +0200  Overcast        rain            13.28
# 50  2006-04-11 02:00:00.000 +0200  Overcast        rain             8.63
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 46                     14.42      0.58              20.01
# 47                     14.26      0.59              16.50
# 48                     13.77      0.60              17.10
# 49                     13.28      0.63              14.36
# 50                      5.47      0.87              22.04
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 46                   159.0            15.83         0.0               1007.85
# 47                   168.0            14.96         0.0               1007.89
# 48                   160.0            15.83         0.0               1007.36
# 49                   160.0            15.83         0.0               1007.26
# 50                    32.0             6.70         0.0               1005.10
#
#                         Daily Summary
# 46  Mostly cloudy throughout the day.
# 47  Mostly cloudy throughout the day.
# 48              Foggy in the evening.
# 49              Foggy in the evening.
# 50              Foggy in the evening.

# %%
# Formatting Date Column. This can be used to identify any seasonality and trends
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'], errors='coerce')
# Extracting the relevant components
data["Time"] = [d.time() for d in data['Formatted Date']]
data["Time"] = data["Time"].astype(str)
data["Time"] = data["Time"].str.split(':').str[0].astype(int)
data["Date"] = [d.date() for d in data['Formatted Date']]
data["Date"]= data["Date"].astype(str)
data["Year"] = data["Date"].str.split('-').str[0].astype(int)
data["Month"] = data["Date"].str.split('-').str[1].astype(int)
data["Day"] = data["Date"].str.split('-').str[2].astype(int)
# Dropping the original column 
data = data.drop(columns=['Formatted Date','Date'], axis=1)

# %% [markdown]
# * #### Redundant Columns Treatment

# %%
# It can be seen that the feature "Loud Cover" have only value '0' and mean and other statistical overview also support the deduction. Hence, it is the redundant column
data["Loud Cover"].value_counts()
# Out:
# 0.0    34379
# Name: Loud Cover, dtype: int64

# %%
# Removing 'Loud Cover'
data.drop(columns=["Loud Cover"], axis=1, inplace=True)
data.head()
# Out:
#      Summary Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 46  Overcast        rain            14.42                     14.42      0.58
# 47  Overcast        rain            14.26                     14.26      0.59
# 48  Overcast        rain            13.77                     13.77      0.60
# 49  Overcast        rain            13.28                     13.28      0.63
# 50  Overcast        rain             8.63                      5.47      0.87
#
#     Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 46              20.01                   159.0            15.83
# 47              16.50                   168.0            14.96
# 48              17.10                   160.0            15.83
# 49              14.36                   160.0            15.83
# 50              22.04                    32.0             6.70
#
#     Pressure (millibars)                      Daily Summary  Time  Year  \
# 46               1007.85  Mostly cloudy throughout the day.    22  2006
# 47               1007.89  Mostly cloudy throughout the day.    23  2006
# 48               1007.36              Foggy in the evening.     0  2006
# 49               1007.26              Foggy in the evening.     1  2006
# 50               1005.10              Foggy in the evening.     2  2006
#
#     Month  Day
# 46      4   10
# 47      4   10
# 48      4   11
# 49      4   11
# 50      4   11

# %% [markdown]
# * #### Outlier Treatment

# %%
# Different types of columns
numeric_columns = list(data.select_dtypes(include=['float64', 'int64']).columns)
categorical_columns = list(data.select_dtypes(include=['object']).columns)
continuous_columns = [i for i in numeric_columns if len(list(data[i].unique()))>=25]
discrete_columns = [i for i in numeric_columns if len(list(data[i].unique()))<25]
print("Numerical Columns: ", numeric_columns)
print()
print("Categorical Columns: ", categorical_columns)
print()
print("Continuous Columns: ", continuous_columns)
print()
print("Discrete Columns: ", discrete_columns)
# Out:
# Numerical Columns:  ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)', 'Time', 'Year', 'Month', 'Day']
#
# Categorical Columns:  ['Summary', 'Precip Type', 'Daily Summary']
#
# Continuous Columns:  ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)', 'Day']
#
# Discrete Columns:  ['Time', 'Year', 'Month']

# %%
# Plotting for outliers in the data.
plt.figure(figsize=(18, 8)) 
sns.boxplot(data=data[numeric_columns])
plt.show()

# %%
# Removing Outliers
data = remove_outliers(data, "Pressure (millibars)")
data = remove_outliers(data, "Wind Speed (km/h)")
data = remove_outliers(data, "Humidity")
data = remove_outliers(data, "Temperature (C)")
data = remove_outliers(data, "Apparent Temperature (C)")

plt.figure(figsize=(18, 8)) 
sns.boxplot(data=data[numeric_columns])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Exploratory Data Analysis

# %% [markdown]
# * #### Checking skewness of the numerical features

# %%
# Numerical columns analysis
for i in numeric_columns:
    histogram_boxplot(data,i)

# %% [markdown]
# * #### Checking distribution of categorical features(Summary and Precip Type)

# %%
# Categorical columns analysis
for i in categorical_columns:
    if i in ['Daily Summary','Time']:
        pass
    else:
        labeled_barplot(data, i)

# %% [markdown]
# * #### Relations between numerical features & Target variable "Summary"

# %%
# Multivariate analysis
for i in numeric_columns:
    distribution_plot_wrt_target(data, i, "Summary")

# %% [markdown]
# * #### Relations between categorical features & Target variable "Summary"

# %%
# Stacked barplot
stacked_barplot(data,"Precip Type" , 'Summary')
# Out:
# Summary      Clear  Foggy  Overcast    All
# Precip Type
# All           8248   6914     15375  30537
# rain          7052   4025     12889  23966
# snow          1196   2889      2486   6571
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Data Pre-processing & Feature Engineering

# %% [markdown]
# * #### Classes Distribution

# %%
# Checking whether the target variable is balanced or unbalanced
counts = data["Summary"].value_counts()
total = counts.sum()
percentages = (counts / total) * 100
print(percentages)
print()
print("The classes are satifactory balanced")
# Out:
# Overcast    50.348757
# Clear       27.009857
# Foggy       22.641386
# Name: Summary, dtype: float64
#
# The classes are satifactory balanced

# %% [markdown]
# * #### Dataset Split

# %%
# Input features dataset
input_df = data.drop(columns="Summary", axis=1)
input_df.head()
# Out:
#    Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 46        rain            14.42                     14.42      0.58
# 47        rain            14.26                     14.26      0.59
# 48        rain            13.77                     13.77      0.60
# 49        rain            13.28                     13.28      0.63
# 50        rain             8.63                      5.47      0.87
#
#     Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 46              20.01                   159.0            15.83
# 47              16.50                   168.0            14.96
# 48              17.10                   160.0            15.83
# 49              14.36                   160.0            15.83
# 50              22.04                    32.0             6.70
#
#     Pressure (millibars)                      Daily Summary  Time  Year  \
# 46               1007.85  Mostly cloudy throughout the day.    22  2006
# 47               1007.89  Mostly cloudy throughout the day.    23  2006
# 48               1007.36              Foggy in the evening.     0  2006
# 49               1007.26              Foggy in the evening.     1  2006
# 50               1005.10              Foggy in the evening.     2  2006
#
#     Month  Day
# 46      4   10
# 47      4   10
# 48      4   11
# 49      4   11
# 50      4   11

# %%
# Target variable 
# Applying mapping
encoder = LabelEncoder()
y = data["Summary"]
y = encoder.fit_transform(y)

# Checking the mapping of the classes
class_mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
for class_label, class_number in class_mapping.items():
    print(f"Class '{class_label}' is labeled as {class_number}")
# Out:
# Class 'Clear' is labeled as 0
# Class 'Foggy' is labeled as 1
# Class 'Overcast' is labeled as 2

# %% [markdown]
# * #### Categorical Features Encoding

# %%
# As "Precip Type" have only 2 values, hence applying binary encoding
mapping = {'rain': 0, 'snow': 1}
input_df['Precip Type'] = input_df['Precip Type'].map(mapping)

# %%
# As "Daily Summary" have 221 unique values, hence applying Frequency encoding
# Creating a new column for frequency encoding and removing previous column
input_df['Daily Summary Frequency'] = input_df['Daily Summary'].map(input_df['Daily Summary'].value_counts(normalize=True))
input_df.drop(columns=['Daily Summary'], axis=1, inplace=True)
# Checking data
input_df.head()
# Out:
#     Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 46            0            14.42                     14.42      0.58
# 47            0            14.26                     14.26      0.59
# 48            0            13.77                     13.77      0.60
# 49            0            13.28                     13.28      0.63
# 50            0             8.63                      5.47      0.87
#
#     Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 46              20.01                   159.0            15.83
# 47              16.50                   168.0            14.96
# 48              17.10                   160.0            15.83
# 49              14.36                   160.0            15.83
# 50              22.04                    32.0             6.70
#
#     Pressure (millibars)  Time  Year  Month  Day  Daily Summary Frequency
# 46               1007.85    22  2006      4   10                 0.177457
# 47               1007.89    23  2006      4   10                 0.177457
# 48               1007.36     0  2006      4   11                 0.004617
# 49               1007.26     1  2006      4   11                 0.004617
# 50               1005.10     2  2006      4   11                 0.004617

# %% [markdown]
# * #### Checking Multicollinearity

# %%
# Confirming multicollinearity using heatmap
sns.set(style="white")
plt.figure(figsize=(12,8))
sns.heatmap(input_df.corr(), annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# As Daily Summary Frequency has a negligible correlation with the other features and it is apparent that the final target is not going to be affected by this, removing it.
input_df.drop(['Daily Summary Frequency'], axis=1, inplace=True)

# %%
# As VIF of Temperature (C) is the highest and Temperature is highly correlated with Apparent Temperature, removing it
input_df.drop(['Temperature (C)'], axis=1, inplace=True)

# %% [markdown]
# * #### Train-Test Split

# %%
# Creating X input set
X = input_df.values
X
# Out:
# array([[0.000e+00, 1.442e+01, 5.800e-01, ..., 2.006e+03, 4.000e+00,
#         1.000e+01],
#        [0.000e+00, 1.426e+01, 5.900e-01, ..., 2.006e+03, 4.000e+00,
#         1.000e+01],
#        [0.000e+00, 1.377e+01, 6.000e-01, ..., 2.006e+03, 4.000e+00,
#         1.100e+01],
#        ...,
#        [0.000e+00, 1.502e+01, 9.000e-01, ..., 2.016e+03, 9.000e+00,
#         9.000e+00],
#        [0.000e+00, 1.387e+01, 9.300e-01, ..., 2.016e+03, 9.000e+00,
#         9.000e+00],
#        [0.000e+00, 1.607e+01, 8.800e-01, ..., 2.016e+03, 9.000e+00,
#         9.000e+00]])

# %%
# Splitting the data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# * #### Normalizing Input Features

# %%
# Apply scaling on the input_df DataFrame
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Model Building

# %% [markdown]
# * #### Parametric Algorithm 1: Logistic Regression Classifier

# %%
# Hyperparameter tuning
parameters = {'solver': ['liblinear', 'saga'], 
              'multi_class':['ovr', 'multinomial'],
              'C':[0.001, 0.01, 10.0],
              'penalty': ['l1', 'l2']}
# Model Creation and Training
model_lr = LogisticRegression(n_jobs=-1)
models_lr = GridSearchCV(estimator=model_lr, param_grid=parameters, cv=4)
models_lr.fit(x_train, y_train)
best_parameters = models_lr.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions for train
best_model_lr = models_lr.best_estimator_
y_pred_lr = best_model_lr.predict(x_train)
# Predictions for test
y_pred_lr_new = best_model_lr.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_lr, y_test, y_pred_lr_new)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best Hyperparameters: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_lr, precision_lr, recall_lr, f1_lr = calculate_classification_metrics(y_test, y_pred_lr_new, "Logistic Regression")
# Out:
# Testing Performance
# Algorithm:  Logistic Regression
#
# Accuracy: 0.834
# Precision: 0.83
# Recall: 0.834
# F1 Score: 0.83

# %% [markdown]
# * #### Parametric Algorithm 2: Gaussian Naive Bayes Classifier

# %%
# Hyperparameter tuning
parameters = {'var_smoothing':[1e-9, 1e-8, 1e-10]}
# Model Creation and Training
model_nb = GaussianNB()
models_nb = GridSearchCV(estimator=model_nb, param_grid=parameters, cv=4)
models_nb.fit(x_train, y_train)
best_parameters = models_nb.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on training data
best_model_nb = models_nb.best_estimator_
y_pred_nb = best_model_nb.predict(x_train)
# Predictions on test data
y_pred_nb_new = best_model_nb.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_nb, y_test, y_pred_nb_new)
# Out:
# Best Hyperparameters: {'var_smoothing': 1e-09}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_nb, precision_nb, recall_nb, f1_nb = calculate_classification_metrics(y_test, y_pred_nb_new, "Gaussian NB")
# Out:
# Testing Performance
# Algorithm:  Gaussian NB
#
# Accuracy: 0.795
# Precision: 0.792
# Recall: 0.795
# F1 Score: 0.792

# %% [markdown]
# * #### Parametric Algorithm 3: Support Vector Machine (SVM) Classifier

# %%
# Hyperparameter tuning
parameters = {'loss':['log_loss','perceptron','hinge','squared_epsilon_insensitive'],
              'penalty': ['l1', 'l2'],
              'alpha':[0.001,0.01,0.0001],
              'learning_rate':['optimal','adaptive','invscaling']}
# Model Creation and Training
model_svc = SGDClassifier()
models_svc = GridSearchCV(estimator=model_svc, param_grid=parameters, cv=4)
models_svc.fit(x_train, y_train)
best_parameters = models_svc.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on train data
best_model_svc = models_svc.best_estimator_
y_pred_svc = best_model_svc.predict(x_train)
# Predictions on test data
y_pred_svc_new = best_model_svc.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_svc, y_test, y_pred_svc_new)
# Out:
# Best Hyperparameters: {'alpha': 0.0001, 'learning_rate': 'optimal', 'loss': 'log_loss', 'penalty': 'l1'}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_svc, precision_svc, recall_svc, f1_svc = calculate_classification_metrics(y_test, y_pred_svc_new, "SVC")
# Out:
# Testing Performance
# Algorithm:  SVC
#
# Accuracy: 0.825
# Precision: 0.823
# Recall: 0.825
# F1 Score: 0.824

# %% [markdown]
# * #### Parametric Algorithm 4: SGD Classifier

# %%
# Hyperparameter tuning
parameters = {'loss':['log_loss','perceptron','hinge','squared_epsilon_insensitive'],
              'penalty': ['l1', 'l2'],
              'alpha':[0.001,0.01,0.0001],
              'learning_rate':['optimal','adaptive','invscaling']}
# Model Creation and Training
model_sgd = SGDClassifier()
models_sgd = GridSearchCV(estimator=model_sgd, param_grid=parameters, cv=4)
models_sgd.fit(x_train, y_train)
best_parameters = models_sgd.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on train data
best_model_sgd = models_sgd.best_estimator_
y_pred_sgd = best_model_sgd.predict(x_train)
# Predictions on test data
y_pred_sgd_new = best_model_sgd.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_sgd, y_test, y_pred_sgd_new)
# Out:
# Best Hyperparameters: {'alpha': 0.001, 'learning_rate': 'optimal', 'loss': 'log_loss', 'penalty': 'l1'}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_sgd, precision_sgd, recall_sgd, f1_sgd = calculate_classification_metrics(y_test, y_pred_sgd_new, "SGD Classifier")
# Out:
# Testing Performance
# Algorithm:  SGD Classifier
#
# Accuracy: 0.823
# Precision: 0.821
# Recall: 0.823
# F1 Score: 0.822

# %% [markdown]
# * #### Non-Parametric Algorithm 1: Decision Tree Classifier

# %%
# Hyperparameter tuning
parameters = {'criterion':['gini', 'entropy', 'log_loss'], 
              'max_depth': [None, 5, 10],
              'min_samples_split': [None, 2, 5],
              'splitter':['best','random']}
# Model Creation and Training
model_dt = DecisionTreeClassifier()
models_dt = GridSearchCV(estimator=model_dt, param_grid=parameters, cv=4)
models_dt.fit(x_train, y_train)
best_parameters = models_dt.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on train data
best_model_dt = models_dt.best_estimator_
y_pred_dt = best_model_dt.predict(x_train)
# Predictions on test data
y_pred_dt_new = best_model_dt.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_dt, y_test, y_pred_dt_new)
# Out:
# Best Hyperparameters: {'criterion': 'log_loss', 'max_depth': None, 'min_samples_split': 2, 'splitter': 'best'}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_dt, precision_dt, recall_dt, f1_dt = calculate_classification_metrics(y_test, y_pred_dt_new, "Decision Tree")
# Out:
# Testing Performance
# Algorithm:  Decision Tree
#
# Accuracy: 0.889
# Precision: 0.89
# Recall: 0.889
# F1 Score: 0.89

# %% [markdown]
# * #### Non-Parametric Algorithm 2: K Nearest Neighbours Classifier

# %%
# Hyperparameter tuning
parameters = {'weights': ['uniform', 'distance'],
            'algorithm': ['auto', 'ball_tree','kd_tree','brute'],
            'p': [1,2]}
# Model Creation and Training
model_knn = KNeighborsClassifier(n_neighbors=5)
models_knn = GridSearchCV(estimator=model_knn, param_grid=parameters, cv=4)
models_knn.fit(x_train, y_train)
best_parameters = models_knn.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on train data
best_model_knn = models_knn.best_estimator_
y_pred_knn = best_model_knn.predict(x_train)
# Predictions on test data
y_pred_knn_new = best_model_knn.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_knn, y_test, y_pred_knn_new)
# Out:
# Best Hyperparameters: {'algorithm': 'auto', 'p': 1, 'weights': 'distance'}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_knn, precision_knn, recall_knn, f1_knn = calculate_classification_metrics(y_test, y_pred_knn_new, "KNN")
# Out:
# Testing Performance
# Algorithm:  KNN
#
# Accuracy: 0.905
# Precision: 0.905
# Recall: 0.905
# F1 Score: 0.905

# %% [markdown]
# * #### Non-Parametric Algorithm 3: Random Forest Classifier

# %%
# Hyperparameter tuning
parameters = {'max_depth': [None, 5],
            'class_weight': [None, 'balanced'],
            'min_samples_split': [None, 2, 5]}
# Model Creation and Training
model_rf = RandomForestClassifier()
models_rf = GridSearchCV(estimator=model_rf, param_grid=parameters, cv=4)
models_rf.fit(x_train, y_train)
best_parameters = models_rf.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on train data
best_model_rf = models_rf.best_estimator_
y_pred_rf = best_model_rf.predict(x_train)
# Predictions on test data
y_pred_rf_new = best_model_rf.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_rf, y_test, y_pred_rf_new)
# Out:
# Best Hyperparameters: {'class_weight': 'balanced', 'max_depth': None, 'min_samples_split': 2}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_rf, precision_rf, recall_rf, f1_rf = calculate_classification_metrics(y_test, y_pred_rf_new, "Random Forest")
# Out:
# Testing Performance
# Algorithm:  Random Forest
#
# Accuracy: 0.941
# Precision: 0.941
# Recall: 0.941
# F1 Score: 0.94

# %% [markdown]
# * #### Non-Parametric Algorithm 4: Extra Trees Classifier

# %%
# Hyperparameter tuning
parameters = {'max_depth': [None, 5],
            'class_weight': [None, 'balanced'],
            'min_samples_split': [None, 2, 5],
            'criterion':['gini','log_loss','entropy']}
# Model Creation and Training
model_et = ExtraTreesClassifier()
models_et = GridSearchCV(estimator=model_et, param_grid=parameters, cv=4)
models_et.fit(x_train, y_train)
best_parameters = models_et.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on train data
best_model_et = models_et.best_estimator_
y_pred_et = best_model_et.predict(x_train)
# Predictions on test data
y_pred_et_new = best_model_et.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_et, y_test, y_pred_et_new)
# Out:
# Best Hyperparameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_et, precision_et, recall_et, f1_et = calculate_classification_metrics(y_test, y_pred_et_new, "Extra Trees")
# Out:
# Testing Performance
# Algorithm:  Extra Trees
#
# Accuracy: 0.942
# Precision: 0.942
# Recall: 0.942
# F1 Score: 0.942

# %% [markdown]
# * #### Non-Parametric Algorithm 5: Gradient Boosting Classifier

# %%
# Hyperparameter tuning
parameters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 5, 7]
}
# Model creation and training
model_gb = GradientBoostingClassifier()
models_gb = GridSearchCV(estimator=model_gb, param_grid=parameters, cv=4)
models_gb.fit(x_train, y_train)
best_parameters = models_gb.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions on the training data
best_model_gb = models_gb.best_estimator_
y_pred_gb = best_model_gb.predict(x_train)
# Predictions on the test data
y_pred_gb_new= best_model_gb.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_gb, y_test, y_pred_gb_new)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 150}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_gb, precision_gb, recall_gb, f1_gb = calculate_classification_metrics(y_test, y_pred_gb_new, "Gradient Boosting Classifier")
# Out:
# Testing Performance
# Algorithm:  Gradient Boosting Classifier
#
# Accuracy: 0.942
# Precision: 0.942
# Recall: 0.942
# F1 Score: 0.942

# %% [markdown]
# * #### Non-Parametric Algorithm 6: Bagging Classifier

# %%
# Hyperparameter tuning
parameters = {
    'n_estimators': [50, 100, 200],
    'max_samples': [0.5, 0.7, 0.9],
    'max_features': [0.5, 0.7, 0.9]
}
# Model creation and training
model_bagging = BaggingClassifier()
models_bagging = GridSearchCV(estimator=model_bagging, param_grid=parameters, cv=4)
models_bagging.fit(x_train, y_train)
best_parameters = models_bagging.best_params_
print("Best Hyperparameters:", best_parameters)
print()
# Predictions for train
best_model_bagging = models_bagging.best_estimator_
y_pred_bagging = best_model_bagging.predict(x_train)
# Predictions for test
y_pred_bagging_new= best_model_bagging.predict(x_test)
checking_overfitting_undefitting(y_train, y_pred_bagging, y_test, y_pred_bagging_new)
# Out:
# Best Hyperparameters: {'max_features': 0.7, 'max_samples': 0.9, 'n_estimators': 100}
#
# Model is not underfitting/overfitting.

# %%
# Evaluation Metrics Calculation
print("Testing Performance")
accuracy_bc, precision_bc, recall_bc, f1_bc = calculate_classification_metrics(y_test, y_pred_bagging_new, "Bagging Classifier")
# Out:
# Testing Performance
# Algorithm:  Bagging Classifier
#
# Accuracy: 0.94
# Precision: 0.94
# Recall: 0.94
# F1 Score: 0.94

# %%
# Results
print("Testing Performances for Machine Learning Algorithms")
result = pd.DataFrame({"Algorithms":['Logistic Regression', "Gaussian Naive Bayes", "SVC", "SGD Classifier", "Decision Tree", "KNN","Random Forest", "Extra Trees Classifier", "Bagging Classifier","Gradient Boosting Classifier"],
                       "Accuracy":[accuracy_lr, accuracy_nb, accuracy_svc, accuracy_sgd, accuracy_dt, accuracy_knn, accuracy_rf, accuracy_et, accuracy_bc, accuracy_gb],
                       "Precision":[precision_lr, precision_nb, precision_svc, precision_sgd, precision_dt, precision_knn, precision_rf, precision_et, precision_bc, precision_gb],
                       "Recall":[recall_lr, recall_nb, recall_svc, recall_sgd, recall_dt, recall_knn, recall_rf, recall_et, recall_bc, recall_gb],
                       "F1 Score":[f1_lr, f1_nb, f1_svc, f1_sgd, f1_dt, f1_knn, f1_rf, f1_et, f1_bc, f1_gb]}).set_index('Algorithms')
result
# Out:
# Testing Performances for Machine Learning Algorithms
#                               Accuracy  Precision  Recall  F1 Score
# Algorithms
# Logistic Regression              0.834      0.830   0.834     0.830
# Gaussian Naive Bayes             0.795      0.792   0.795     0.792
# SVC                              0.825      0.823   0.825     0.824
# SGD Classifier                   0.823      0.821   0.823     0.822
# Decision Tree                    0.889      0.890   0.889     0.890
# KNN                              0.905      0.905   0.905     0.905
# Random Forest                    0.941      0.941   0.941     0.940
# Extra Trees Classifier           0.942      0.942   0.942     0.942
# Bagging Classifier               0.940      0.940   0.940     0.940
# Gradient Boosting Classifier     0.942      0.942   0.942     0.942

# %%
# Saving sklearn machine learning models
models = [best_model_dt, best_model_lr, best_model_knn, best_model_et, best_model_nb, best_model_rf, best_model_sgd, best_model_svc, best_model_gb, best_model_bagging]
names = ["dt","lr","knn","et","nb","rf","sgd","svc","gb","bg"]
for i in range(len(models)):
    joblib.dump(models[i],names[i]+".pkl")

# %% [markdown]
# ---

# %% [markdown]
# * #### Neural Network Preprocessing

# %%
# Hyperparameters for ANN & RNN
num_classes = 3
epochs = 150
input_dimension = x_train.shape[1]
batch_size = 64
learning_rate = 0.001

# %%
# Converting labels to one-hot encoded format
y_train_encoded = tf.keras.utils.to_categorical(y_train, num_classes)
y_test_encoded = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Reshaping input data for RNN
x_train_reshaped = np.expand_dims(x_train, axis=2)
x_test_reshaped = np.expand_dims(x_test, axis=2)

# %% [markdown]
# * #### Neural Network 1: Feed Forward Neural Network

# %%
# Architecture 1: 64-64-128-3 Feed Forward Neural Network
# Defining the ANN architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(64, activation='relu', input_dim=input_dimension)) 
model.add(tf.keras.layers.Dense(64, activation='relu')) 
model.add(tf.keras.layers.Dense(128, activation='relu')) 
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(num_classes, activation='softmax')) 
# Model Compilation
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Stopping early to avoid overfitting
stop_callback = myCallback()

# Training
history = model.fit(x_train, y_train_encoded, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test_encoded), callbacks=[stop_callback])

# Plotting training and testing curves
default_size = plt.rcParams['figure.figsize']
fig = plt.figure(figsize=[default_size[0] * 2, default_size[1]])

fig.add_subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'accuracy')          # Train accuracy (blue)
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')  # Valid accuracy (orange)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend(loc='lower right')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')          # Train loss (blue)
plt.plot(history.history['val_loss'], label='val_loss')  # Valid loss (orange)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/150
# 382/382 [==============================] - 2s 3ms/step - loss: 0.5043 - accuracy: 0.7747 - val_loss: 0.3971 - val_accuracy: 0.8247
# Epoch 2/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.3825 - accuracy: 0.8297 - val_loss: 0.3621 - val_accuracy: 0.8412
# Epoch 3/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3539 - accuracy: 0.8443 - val_loss: 0.3480 - val_accuracy: 0.8445
# Epoch 4/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3341 - accuracy: 0.8532 - val_loss: 0.3265 - val_accuracy: 0.8587
# Epoch 5/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3157 - accuracy: 0.8629 - val_loss: 0.3066 - val_accuracy: 0.8702
# Epoch 6/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3069 - accuracy: 0.8664 - val_loss: 0.3100 - val_accuracy: 0.8676
# Epoch 7/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2967 - accuracy: 0.8709 - val_loss: 0.3110 - val_accuracy: 0.8643
# Epoch 8/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2837 - accuracy: 0.8789 - val_loss: 0.2968 - val_accuracy: 0.8700
# Epoch 9/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2795 - accuracy: 0.8805 - val_loss: 0.2996 - val_accuracy: 0.8774
# Epoch 10/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2718 - accuracy: 0.8843 - val_loss: 0.2812 - val_accuracy: 0.8820
# Epoch 11/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2653 - accuracy: 0.8880 - val_loss: 0.2977 - val_accuracy: 0.8725
# Epoch 12/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2591 - accuracy: 0.8900 - val_loss: 0.2860 - val_accuracy: 0.8756
# Epoch 13/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2531 - accuracy: 0.8937 - val_loss: 0.2659 - val_accuracy: 0.8893
# Epoch 14/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2482 - accuracy: 0.8951 - val_loss: 0.2963 - val_accuracy: 0.8743
# Epoch 15/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2437 - accuracy: 0.8974 - val_loss: 0.2738 - val_accuracy: 0.8846
# Epoch 16/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2366 - accuracy: 0.8998 - val_loss: 0.2785 - val_accuracy: 0.8826
# Epoch 17/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2306 - accuracy: 0.9028 - val_loss: 0.2651 - val_accuracy: 0.8942
# Epoch 18/150
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2309 - accuracy: 0.9033 - val_loss: 0.2545 - val_accuracy: 0.8942
# Epoch 19/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2248 - accuracy: 0.9055 - val_loss: 0.2657 - val_accuracy: 0.8918
# Epoch 20/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2218 - accuracy: 0.9083 - val_loss: 0.2572 - val_accuracy: 0.8952
# Epoch 21/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2153 - accuracy: 0.9104 - val_loss: 0.2460 - val_accuracy: 0.8978
# Epoch 22/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2123 - accuracy: 0.9109 - val_loss: 0.2463 - val_accuracy: 0.8977
# Epoch 23/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2126 - accuracy: 0.9109 - val_loss: 0.2508 - val_accuracy: 0.8965
# Epoch 24/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.2081 - accuracy: 0.9135 - val_loss: 0.2573 - val_accuracy: 0.8949
# Epoch 25/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.
150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1377 - accuracy: 0.9447 - val_loss: 0.2620 - val_accuracy: 0.9036
# Epoch 57/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1374 - accuracy: 0.9445 - val_loss: 0.2520 - val_accuracy: 0.9093
# Epoch 58/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1320 - accuracy: 0.9471 - val_loss: 0.2603 - val_accuracy: 0.9091
# Epoch 59/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1295 - accuracy: 0.9476 - val_loss: 0.2571 - val_accuracy: 0.9093
# Epoch 60/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1341 - accuracy: 0.9469 - val_loss: 0.2640 - val_accuracy: 0.9103
# Epoch 61/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1309 - accuracy: 0.9474 - val_loss: 0.2564 - val_accuracy: 0.9075
# Epoch 62/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1269 - accuracy: 0.9492 - val_loss: 0.2736 - val_accuracy: 0.9098
# Epoch 63/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1256 - accuracy: 0.9496 - val_loss: 0.2754 - val_accuracy: 0.9080
# Epoch 64/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1265 - accuracy: 0.9478 - val_loss: 0.2547 - val_accuracy: 0.9129
# Epoch 65/150
# 371/382 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9498
# Validation and training accuracies are high so cancelling training!
# 382/382 [==============================] - 1s 3ms/step - loss: 0.1249 - accuracy: 0.9503 - val_loss: 0.2587 - val_accuracy: 0.9090

# %%
# Evaluating the model on test data
test_loss_0, test_accuracy_0 = model.evaluate(x_test, y_test_encoded, verbose=0)
print('Test Loss:', test_loss_0)
print('Test Accuracy:', test_accuracy_0)
# Saving the model to a file
model.save('FFNN.h5')
# Out:
# Test Loss: 0.25870582461357117
# Test Accuracy: 0.9089718461036682

# %%
# Architecture 2: 32-256-3 Feed Forward Neural Network with 'relu' and 'softmax'
# Defining the ANN architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(32, activation='relu', input_dim=input_dimension)) 
model.add(tf.keras.layers.Dense(256, activation='relu')) 
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(num_classes, activation='softmax')) 
# Model Compilation
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Stopping early to avoid overfitting
stop_callback = myCallback()
# Training
history = model.fit(x_train, y_train_encoded, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test_encoded), callbacks=[stop_callback])

# Plotting training and testing curves
default_size = plt.rcParams['figure.figsize']
fig = plt.figure(figsize=[default_size[0] * 2, default_size[1]])

fig.add_subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'accuracy')          # Train accuracy (blue)
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')  # Valid accuracy (orange)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend(loc='lower right')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')          # Train loss (blue)
plt.plot(history.history['val_loss'], label='val_loss')  # Valid loss (orange)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/150
# 382/382 [==============================] - 2s 3ms/step - loss: 1.1043 - accuracy: 0.3972 - val_loss: 1.0501 - val_accuracy: 0.4992
# Epoch 2/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0188 - accuracy: 0.5037 - val_loss: 0.9870 - val_accuracy: 0.5005
# Epoch 3/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9643 - accuracy: 0.5157 - val_loss: 0.9385 - val_accuracy: 0.5100
# Epoch 4/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9195 - accuracy: 0.5401 - val_loss: 0.8955 - val_accuracy: 0.5445
# Epoch 5/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.8769 - accuracy: 0.5770 - val_loss: 0.8560 - val_accuracy: 0.5881
# Epoch 6/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.8407 - accuracy: 0.6153 - val_loss: 0.8195 - val_accuracy: 0.6282
# Epoch 7/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.8069 - accuracy: 0.6437 - val_loss: 0.7856 - val_accuracy: 0.6557
# Epoch 8/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.7746 - accuracy: 0.6680 - val_loss: 0.7547 - val_accuracy: 0.6794
# Epoch 9/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.
150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3948 - accuracy: 0.8284 - val_loss: 0.3862 - val_accuracy: 0.8353
# Epoch 135/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3946 - accuracy: 0.8276 - val_loss: 0.3859 - val_accuracy: 0.8355
# Epoch 136/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3940 - accuracy: 0.8288 - val_loss: 0.3854 - val_accuracy: 0.8364
# Epoch 137/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3935 - accuracy: 0.8281 - val_loss: 0.3851 - val_accuracy: 0.8356
# Epoch 138/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3946 - accuracy: 0.8269 - val_loss: 0.3848 - val_accuracy: 0.8358
# Epoch 139/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3918 - accuracy: 0.8295 - val_loss: 0.3844 - val_accuracy: 0.8364
# Epoch 140/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3923 - accuracy: 0.8289 - val_loss: 0.3839 - val_accuracy: 0.8368
# Epoch 141/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3922 - accuracy: 0.8286 - val_loss: 0.3836 - val_accuracy: 0.8373
# Epoch 142/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3926 - accuracy: 0.8282 - val_loss: 0.3833 - val_accuracy: 0.8374
# Epoch 143/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3920 - accuracy: 0.8289 - val_loss: 0.3830 - val_accuracy: 0.8374
# Epoch 144/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3920 - accuracy: 0.8278 - val_loss: 0.3826 - val_accuracy: 0.8373
# Epoch 145/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3911 - accuracy: 0.8295 - val_loss: 0.3822 - val_accuracy: 0.8374
# Epoch 146/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3905 - accuracy: 0.8292 - val_loss: 0.3819 - val_accuracy: 0.8376
# Epoch 147/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3910 - accuracy: 0.8289 - val_loss: 0.3816 - val_accuracy: 0.8379
# Epoch 148/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3895 - accuracy: 0.8304 - val_loss: 0.3812 - val_accuracy: 0.8386
# Epoch 149/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3890 - accuracy: 0.8313 - val_loss: 0.3809 - val_accuracy: 0.8384
# Epoch 150/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.3875 - accuracy: 0.8325 - val_loss: 0.3806 - val_accuracy: 0.8382

# %%
# Evaluating the model on test data
test_loss_1, test_accuracy_1 = model.evaluate(x_test, y_test_encoded, verbose=0)
print('Test Loss:', test_loss_1)
print('Test Accuracy:', test_accuracy_1)
# Out:
# Test Loss: 0.3805701732635498
# Test Accuracy: 0.8382449150085449

# %%
# Architecture 3: 32-256-3 Feed Forward Neural Network with 'sigmoid' and 'softmax'
# Defining the ANN architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(32, activation='sigmoid', input_dim=input_dimension)) 
model.add(tf.keras.layers.Dense(256, activation='sigmoid')) 
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(num_classes, activation='softmax')) 
# Model Compilation
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Stopping early to avoid overfitting
stop_callback = myCallback()
# Training
history = model.fit(x_train, y_train_encoded, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test_encoded), callbacks=[stop_callback])

# Plotting training and testing curves
default_size = plt.rcParams['figure.figsize']
fig = plt.figure(figsize=[default_size[0] * 2, default_size[1]])

fig.add_subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'accuracy')          # Train accuracy (blue)
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')  # Valid accuracy (orange)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend(loc='lower right')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')          # Train loss (blue)
plt.plot(history.history['val_loss'], label='val_loss')  # Valid loss (orange)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/150
# 382/382 [==============================] - 2s 4ms/step - loss: 1.0822 - accuracy: 0.4856 - val_loss: 1.0296 - val_accuracy: 0.4993
# Epoch 2/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0629 - accuracy: 0.4769 - val_loss: 1.0272 - val_accuracy: 0.4993
# Epoch 3/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0572 - accuracy: 0.4820 - val_loss: 1.0251 - val_accuracy: 0.4993
# Epoch 4/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0512 - accuracy: 0.4814 - val_loss: 1.0230 - val_accuracy: 0.4993
# Epoch 5/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0533 - accuracy: 0.4811 - val_loss: 1.0206 - val_accuracy: 0.4993
# Epoch 6/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0502 - accuracy: 0.4814 - val_loss: 1.0181 - val_accuracy: 0.4993
# Epoch 7/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0435 - accuracy: 0.4857 - val_loss: 1.0162 - val_accuracy: 0.4993
# Epoch 8/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0424 - accuracy: 0.4884 - val_loss: 1.0136 - val_accuracy: 0.4993
# Epoch 9/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0432 - accuracy: 0.4836 - val_loss: 1.0115 - val_accuracy: 0.4993
# Epoch 10/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0374 - accuracy: 0.4899 - val_loss: 1.0096 - val_accuracy: 0.4993
# Epoch 11/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0370 - accuracy: 0.4887 - val_loss: 1.0078 - val_accuracy: 0.4993
# Epoch 12/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0324 - accuracy: 0.4902 - val_loss: 1.0050 - val_accuracy: 0.4993
# Epoch 13/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0310 - accuracy: 0.4908 - val_loss: 1.0029 - val_accuracy: 0.4993
# Epoch 14/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0314 - accuracy: 0.4883 - val_loss: 1.0015 - val_accuracy: 0.4993
# Epoch 15/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0268 - accuracy: 0.4941 - val_loss: 0.9985 - val_accuracy: 0.4993
# Epoch 16/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0268 - accuracy: 0.4935 - val_loss: 0.9966 - val_accuracy: 0.4993
# Epoch 17/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0233 - accuracy: 0.4947 - val_loss: 0.9939 - val_accuracy: 0.4993
# Epoch 18/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0186 - accuracy: 0.4959 - val_loss: 0.9919 - val_accuracy: 0.4993
# Epoch 19/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0167 - accuracy: 0.4962 - val_loss: 0.9898 - val_accuracy: 0.4993
# Epoch 20/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0131 - accuracy: 0.5002 - val_loss: 0.9871 - val_accuracy: 0.4993
# Epoch 21/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0120 - accuracy: 0.4992 - val_loss: 0.9854 - val_accuracy: 0.4993
# Epoch 22/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0088 - accuracy: 0.5002 - val_loss: 0.9825 - val_accuracy: 0.4993
# Epoch 23/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0038 - accuracy: 0.5019 - val_loss: 0.9805 - val_accuracy: 0.4993
# Epoch 24/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0023 - accuracy: 0.5061 - val_loss: 0.9774 - val_accuracy: 0.4993
# Epoch 25/150
# 382/382 [==============================] - 1s 3ms/step - loss: 1.0008 - accuracy: 0.5040 - val_loss: 0.9750 - val_accuracy: 0.4993
# Epoch 26/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9997 - accuracy: 0.5037 - val_loss: 0.9729 - val_accuracy: 0.4993
# Epoch 27/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9992 - accuracy: 0.5055 - val_loss: 0.9699 - val_accuracy: 0.4993
# Epoch 28/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9957 - accuracy: 0.5042 - val_loss: 0.9677 - val_accuracy: 0.4993
# Epoch 29/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9911 - accuracy: 0.5101 - val_loss: 0.9648 - val_accuracy: 0.4993
# Epoch 30/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9883 - accuracy: 0.5099 - val_loss: 0.9619 - val_accuracy: 0.4993
# Epoch 31/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9861 - accuracy: 0.5082 - val_loss: 0.9596 - val_accuracy: 0.4993
# Epoch 32/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9837 - accuracy: 0.5118 - val_loss: 0.9562 - val_accuracy: 0.4993
# Epoch 33/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9830 - accuracy: 0.5113 - val_loss: 0.9541 - val_accuracy: 0.4993
# Epoch 34/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.9750 - accuracy: 0.5148 - val_loss: 0.9504 - val_accuracy: 0.4993
# Epoch 35/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.
150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6802 - accuracy: 0.6824 - val_loss: 0.6320 - val_accuracy: 0.7412
# Epoch 129/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.6860 - val_loss: 0.6297 - val_accuracy: 0.7472
# Epoch 130/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6741 - accuracy: 0.6912 - val_loss: 0.6279 - val_accuracy: 0.7448
# Epoch 131/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6725 - accuracy: 0.6908 - val_loss: 0.6254 - val_accuracy: 0.7561
# Epoch 132/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6750 - accuracy: 0.6880 - val_loss: 0.6235 - val_accuracy: 0.7536
# Epoch 133/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6684 - accuracy: 0.6926 - val_loss: 0.6217 - val_accuracy: 0.7521
# Epoch 134/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6668 - accuracy: 0.6940 - val_loss: 0.6196 - val_accuracy: 0.7559
# Epoch 135/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6692 - accuracy: 0.6916 - val_loss: 0.6175 - val_accuracy: 0.7593
# Epoch 136/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6616 - accuracy: 0.6972 - val_loss: 0.6161 - val_accuracy: 0.7538
# Epoch 137/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6617 - accuracy: 0.6952 - val_loss: 0.6138 - val_accuracy: 0.7603
# Epoch 138/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6603 - accuracy: 0.6969 - val_loss: 0.6128 - val_accuracy: 0.7547
# Epoch 139/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6580 - accuracy: 0.6971 - val_loss: 0.6105 - val_accuracy: 0.7575
# Epoch 140/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6577 - accuracy: 0.6953 - val_loss: 0.6085 - val_accuracy: 0.7600
# Epoch 141/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6553 - accuracy: 0.6957 - val_loss: 0.6065 - val_accuracy: 0.7657
# Epoch 142/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6545 - accuracy: 0.6968 - val_loss: 0.6048 - val_accuracy: 0.7657
# Epoch 143/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6532 - accuracy: 0.6995 - val_loss: 0.6032 - val_accuracy: 0.7654
# Epoch 144/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6472 - accuracy: 0.7036 - val_loss: 0.6016 - val_accuracy: 0.7624
# Epoch 145/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6480 - accuracy: 0.7025 - val_loss: 0.6000 - val_accuracy: 0.7629
# Epoch 146/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6493 - accuracy: 0.7007 - val_loss: 0.5979 - val_accuracy: 0.7685
# Epoch 147/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6443 - accuracy: 0.7029 - val_loss: 0.5965 - val_accuracy: 0.7662
# Epoch 148/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6456 - accuracy: 0.7038 - val_loss: 0.5949 - val_accuracy: 0.7692
# Epoch 149/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6451 - accuracy: 0.7012 - val_loss: 0.5935 - val_accuracy: 0.7670
# Epoch 150/150
# 382/382 [==============================] - 1s 3ms/step - loss: 0.6433 - accuracy: 0.7023 - val_loss: 0.5916 - val_accuracy: 0.7708

# %%
# Evaluating the model on test data
test_loss_2, test_accuracy_2 = model.evaluate(x_test, y_test_encoded, verbose=0)
print('Test Loss:', test_loss_2)
print('Test Accuracy:', test_accuracy_2)
# Out:
# Test Loss: 0.591557502746582
# Test Accuracy: 0.7707924246788025

# %% [markdown]
# * #### Neural Network 2: Recurrent Neural Network

# %%
# Architecture 1: 32-64-128-3 RNN with 'relu' and 'softmax'
# Defining the RNN architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.SimpleRNN(32, activation='relu', input_shape=(input_dimension, 1)))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

# Model Compilation
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Stopping early to avoid overfitting
stop_callback = myCallback()
# Training
history = model.fit(x_train_reshaped, y_train_encoded, epochs=epochs, batch_size=batch_size, validation_data=(x_test_reshaped, y_test_encoded), callbacks=[stop_callback])

# Plotting training and testing curves
default_size = plt.rcParams['figure.figsize']
fig = plt.figure(figsize=[default_size[0] * 2, default_size[1]])

fig.add_subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'accuracy')          # Train accuracy (blue)
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')  # Valid accuracy (orange)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend(loc='lower right')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')          # Train loss (blue)
plt.plot(history.history['val_loss'], label='val_loss')  # Valid loss (orange)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/150
# 382/382 [==============================] - 4s 6ms/step - loss: 0.5846 - accuracy: 0.7260 - val_loss: 0.4339 - val_accuracy: 0.8011
# Epoch 2/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.4063 - accuracy: 0.8155 - val_loss: 0.3742 - val_accuracy: 0.8330
# Epoch 3/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3804 - accuracy: 0.8299 - val_loss: 0.3686 - val_accuracy: 0.8397
# Epoch 4/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3698 - accuracy: 0.8343 - val_loss: 0.3612 - val_accuracy: 0.8373
# Epoch 5/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3614 - accuracy: 0.8379 - val_loss: 0.3520 - val_accuracy: 0.8454
# Epoch 6/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3501 - accuracy: 0.8462 - val_loss: 0.3376 - val_accuracy: 0.8531
# Epoch 7/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3391 - accuracy: 0.8510 - val_loss: 0.3445 - val_accuracy: 0.8505
# Epoch 8/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3370 - accuracy: 0.8503 - val_loss: 0.3313 - val_accuracy: 0.8579
# Epoch 9/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3310 - accuracy: 0.8525 - val_loss: 0.3327 - val_accuracy: 0.8595
# Epoch 10/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3227 - accuracy: 0.8584 - val_loss: 0.3321 - val_accuracy: 0.8533
# Epoch 11/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3173 - accuracy: 0.8600 - val_loss: 0.3128 - val_accuracy: 0.8677
# Epoch 12/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3099 - accuracy: 0.8647 - val_loss: 0.3167 - val_accuracy: 0.8612
# Epoch 13/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3105 - accuracy: 0.8645 - val_loss: 0.3082 - val_accuracy: 0.8656
# Epoch 14/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3050 - accuracy: 0.8680 - val_loss: 0.3109 - val_accuracy: 0.8641
# Epoch 15/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2971 - accuracy: 0.8698 - val_loss: 0.3055 - val_accuracy: 0.8685
# Epoch 16/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2952 - accuracy: 0.8718 - val_loss: 0.3115 - val_accuracy: 0.8689
# Epoch 17/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2913 - accuracy: 0.8739 - val_loss: 0.3031 - val_accuracy: 0.8713
# Epoch 18/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2911 - accuracy: 0.8740 - val_loss: 0.3112 - val_accuracy: 0.8679
# Epoch 19/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2870 - accuracy: 0.8767 - val_loss: 0.3000 - val_accuracy: 0.8731
# Epoch 20/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2787 - accuracy: 0.8803 - val_loss: 0.2918 - val_accuracy: 0.8754
# Epoch 21/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2770 - accuracy: 0.8801 - val_loss: 0.2873 - val_accuracy: 0.8784
# Epoch 22/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2748 - accuracy: 0.8824 - val_loss: 0.2993 - val_accuracy: 0.8726
# Epoch 23/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2746 - accuracy: 0.8820 - val_loss: 0.3117 - val_accuracy: 0.8702
# Epoch 24/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2721 - accuracy: 0.8844 - val_loss: 0.2837 - val_accuracy: 0.8838
# Epoch 25/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2725 - accuracy: 0.8843 - val_loss: 0.2937 - val_accuracy: 0.8762
# Epoch 26/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2675 - accuracy: 0.8851 - val_loss: 0.2870 - val_accuracy: 0.8793
# Epoch 27/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2623 - accuracy: 0.8891 - val_loss: 0.3072 - val_accuracy: 0.8756
# Epoch 28/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2588 - accuracy: 0.8900 - val_loss: 0.2850 - val_accuracy: 0.8813
# Epoch 29/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.
150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2097 - accuracy: 0.9118 - val_loss: 0.2697 - val_accuracy: 0.8893
# Epoch 61/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2037 - accuracy: 0.9141 - val_loss: 0.2700 - val_accuracy: 0.8903
# Epoch 62/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2026 - accuracy: 0.9151 - val_loss: 0.2563 - val_accuracy: 0.9009
# Epoch 63/150
# 382/382 [==============================] - 3s 7ms/step - loss: 0.2034 - accuracy: 0.9157 - val_loss: 0.2604 - val_accuracy: 0.8934
# Epoch 64/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2042 - accuracy: 0.9151 - val_loss: 0.2631 - val_accuracy: 0.8962
# Epoch 65/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2017 - accuracy: 0.9147 - val_loss: 0.2594 - val_accuracy: 0.8993
# Epoch 66/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2016 - accuracy: 0.9162 - val_loss: 0.2625 - val_accuracy: 0.8960
# Epoch 67/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1981 - accuracy: 0.9183 - val_loss: 0.2878 - val_accuracy: 0.8859
# Epoch 68/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2023 - accuracy: 0.9160 - val_loss: 0.2863 - val_accuracy: 0.8870
# Epoch 69/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1961 - accuracy: 0.9176 - val_loss: 0.2709 - val_accuracy: 0.8942
# Epoch 70/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1936 - accuracy: 0.9184 - val_loss: 0.2678 - val_accuracy: 0.8923
# Epoch 71/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1910 - accuracy: 0.9210 - val_loss: 0.2825 - val_accuracy: 0.8898
# Epoch 72/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1974 - accuracy: 0.9195 - val_loss: 0.2705 - val_accuracy: 0.8921
# Epoch 73/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1966 - accuracy: 0.9183 - val_loss: 0.2683 - val_accuracy: 0.8941
# Epoch 74/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1893 - accuracy: 0.9220 - val_loss: 0.2702 - val_accuracy: 0.8919
# Epoch 75/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1940 - accuracy: 0.9192 - val_loss: 0.2707 - val_accuracy: 0.8946
# Epoch 76/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1921 - accuracy: 0.9188 - val_loss: 0.3043 - val_accuracy: 0.8824
# Epoch 77/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1893 - accuracy: 0.9216 - val_loss: 0.2707 - val_accuracy: 0.8972
# Epoch 78/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1844 - accuracy: 0.9232 - val_loss: 0.2839 - val_accuracy: 0.8895
# Epoch 79/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1869 - accuracy: 0.9228 - val_loss: 0.2703 - val_accuracy: 0.8921
# Epoch 80/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1875 - accuracy: 0.9202 - val_loss: 0.2693 - val_accuracy: 0.8918
# Epoch 81/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1812 - accuracy: 0.9244 - val_loss: 0.2875 - val_accuracy: 0.8929
# Epoch 82/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1771 - accuracy: 0.9279 - val_loss: 0.2790 - val_accuracy: 0.8926
# Epoch 83/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1833 - accuracy: 0.9243 - val_loss: 0.2714 - val_accuracy: 0.8951
# Epoch 84/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1815 - accuracy: 0.9249 - val_loss: 0.2661 - val_accuracy: 0.8978
# Epoch 85/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1786 - accuracy: 0.9268 - val_loss: 0.2800 - val_accuracy: 0.8947
# Epoch 86/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1854 - accuracy: 0.9230 - val_loss: 0.2643 - val_accuracy: 0.8969
# Epoch 87/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1788 - accuracy: 0.9232 - val_loss: 0.2630 - val_accuracy: 0.9009
# Epoch 88/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1784 - accuracy: 0.9250 - val_loss: 0.2723 - val_accuracy: 0.8962
# Epoch 89/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1788 - accuracy: 0.9262 - val_loss: 0.2695 - val_accuracy: 0.9044
# Epoch 90/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.
150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1370 - accuracy: 0.9426 - val_loss: 0.2896 - val_accuracy: 0.9021

# %%
# Evaluating the model on test data
test_loss_3, test_accuracy_3 = model.evaluate(x_test_reshaped, y_test_encoded, verbose=0)
print('Test Loss:', test_loss_3)
print('Test Accuracy:', test_accuracy_3)
# Out:
# Test Loss: 0.2896172106266022
# Test Accuracy: 0.9020956158638

# %%
# Architecture 2: 32-256-3 RNN with 'relu' and 'softmax'
# Defining the RNN architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.SimpleRNN(32, activation='relu', input_shape=(input_dimension, 1)))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

# Model Compilation
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Stopping early to avoid overfitting
stop_callback = myCallback()
# Training
history = model.fit(x_train_reshaped, y_train_encoded, epochs=epochs, batch_size=batch_size, validation_data=(x_test_reshaped, y_test_encoded), callbacks=[stop_callback])

# Plotting training and testing curves
default_size = plt.rcParams['figure.figsize']
fig = plt.figure(figsize=[default_size[0] * 2, default_size[1]])

fig.add_subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'accuracy')          # Train accuracy (blue)
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')  # Valid accuracy (orange)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend(loc='lower right')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')          # Train loss (blue)
plt.plot(history.history['val_loss'], label='val_loss')  # Valid loss (orange)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/150
# 382/382 [==============================] - 4s 6ms/step - loss: 0.5867 - accuracy: 0.7252 - val_loss: 0.4152 - val_accuracy: 0.8171
# Epoch 2/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.4130 - accuracy: 0.8154 - val_loss: 0.4031 - val_accuracy: 0.8211
# Epoch 3/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3859 - accuracy: 0.8293 - val_loss: 0.3699 - val_accuracy: 0.8381
# Epoch 4/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3741 - accuracy: 0.8347 - val_loss: 0.3608 - val_accuracy: 0.8412
# Epoch 5/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3633 - accuracy: 0.8404 - val_loss: 0.3758 - val_accuracy: 0.8328
# Epoch 6/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3524 - accuracy: 0.8434 - val_loss: 0.3458 - val_accuracy: 0.8515
# Epoch 7/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3469 - accuracy: 0.8472 - val_loss: 0.3533 - val_accuracy: 0.8446
# Epoch 8/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3413 - accuracy: 0.8492 - val_loss: 0.3437 - val_accuracy: 0.8505
# Epoch 9/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3325 - accuracy: 0.8533 - val_loss: 0.3396 - val_accuracy: 0.8515
# Epoch 10/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3299 - accuracy: 0.8549 - val_loss: 0.3842 - val_accuracy: 0.8317
# Epoch 11/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3258 - accuracy: 0.8583 - val_loss: 0.3364 - val_accuracy: 0.8572
# Epoch 12/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3198 - accuracy: 0.8600 - val_loss: 0.3317 - val_accuracy: 0.8551
# Epoch 13/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3160 - accuracy: 0.8597 - val_loss: 0.3246 - val_accuracy: 0.8603
# Epoch 14/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3146 - accuracy: 0.8630 - val_loss: 0.3138 - val_accuracy: 0.8623
# Epoch 15/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3099 - accuracy: 0.8645 - val_loss: 0.3563 - val_accuracy: 0.8423
# Epoch 16/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3055 - accuracy: 0.8683 - val_loss: 0.3156 - val_accuracy: 0.8626
# Epoch 17/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3056 - accuracy: 0.8676 - val_loss: 0.3316 - val_accuracy: 0.8551
# Epoch 18/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3003 - accuracy: 0.8702 - val_loss: 0.3236 - val_accuracy: 0.8520
# Epoch 19/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2981 - accuracy: 0.8712 - val_loss: 0.3322 - val_accuracy: 0.8564
# Epoch 20/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2976 - accuracy: 0.8692 - val_loss: 0.3070 - val_accuracy: 0.8672
# Epoch 21/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2897 - accuracy: 0.8748 - val_loss: 0.3326 - val_accuracy: 0.8543
# Epoch 22/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2886 - accuracy: 0.8738 - val_loss: 0.3112 - val_accuracy: 0.8657
# Epoch 23/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2865 - accuracy: 0.8760 - val_loss: 0.3119 - val_accuracy: 0.8621
# Epoch 24/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2854 - accuracy: 0.8775 - val_loss: 0.3141 - val_accuracy: 0.8667
# Epoch 25/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2867 - accuracy: 0.8742 - val_loss: 0.3294 - val_accuracy: 0.8592
# Epoch 26/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2884 - accuracy: 0.8774 - val_loss: 0.3034 - val_accuracy: 0.8695
# Epoch 27/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2832 - accuracy: 0.8781 - val_loss: 0.3056 - val_accuracy: 0.8697
# Epoch 28/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2793 - accuracy: 0.8788 - val_loss: 0.3072 - val_accuracy: 0.8653
# Epoch 29/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2781 - accuracy: 0.8803 - val_loss: 0.2936 - val_accuracy: 0.8708
# Epoch 30/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2719 - accuracy: 0.8826 - val_loss: 0.2996 - val_accuracy: 0.8679
# Epoch 31/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2742 - accuracy: 0.8833 - val_loss: 0.2873 - val_accuracy: 0.8780
# Epoch 32/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2686 - accuracy: 0.8842 - val_loss: 0.2883 - val_accuracy: 0.8734
# Epoch 33/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2718 - accuracy: 0.8815 - val_loss: 0.2913 - val_accuracy: 0.8738
# Epoch 34/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2653 - accuracy: 0.8872 - val_loss: 0.3009 - val_accuracy: 0.8689
# Epoch 35/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2657 - accuracy: 0.8862 - val_loss: 0.3012 - val_accuracy: 0.8687
# Epoch 36/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2630 - accuracy: 0.8886 - val_loss: 0.2867 - val_accuracy: 0.8780
# Epoch 37/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2605 - accuracy: 0.8898 - val_loss: 0.2943 - val_accuracy: 0.8734
# Epoch 38/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2584 - accuracy: 0.8892 - val_loss: 0.2864 - val_accuracy: 0.8748
# Epoch 39/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2594 - accuracy: 0.8904 - val_loss: 0.3037 - val_accuracy: 0.8664
# Epoch 40/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2569 - accuracy: 0.8906 - val_loss: 0.2986 - val_accuracy: 0.8726
# Epoch 41/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2575 - accuracy: 0.8903 - val_loss: 0.2974 - val_accuracy: 0.8738
# Epoch 42/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2579 - accuracy: 0.8889 - val_loss: 0.2909 - val_accuracy: 0.8743
# Epoch 43/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2499 - accuracy: 0.8926 - val_loss: 0.2944 - val_accuracy: 0.8751
# Epoch 44/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2466 - accuracy: 0.8958 - val_loss: 0.2849 - val_accuracy: 0.8793
# Epoch 45/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2518 - accuracy: 0.8945 - val_loss: 0.3078 - val_accuracy: 0.8671
# Epoch 46/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2500 - accuracy: 0.8945 - val_loss: 0.2736 - val_accuracy: 0.8867
# Epoch 47/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2480 - accuracy: 0.8952 - val_loss: 0.2666 - val_accuracy: 0.8877
# Epoch 48/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2463 - accuracy: 0.8957 - val_loss: 0.2870 - val_accuracy: 0.8806
# Epoch 49/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2513 - accuracy: 0.8934 - val_loss: 0.2880 - val_accuracy: 0.8759
# Epoch 50/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2457 - accuracy: 0.8967 - val_loss: 0.2893 - val_accuracy: 0.8748
# Epoch 51/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2476 - accuracy: 0.8952 - val_loss: 0.2723 - val_accuracy: 0.8841
# Epoch 52/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2424 - accuracy: 0.8973 - val_loss: 0.2849 - val_accuracy: 0.8774
# Epoch 53/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2400 - accuracy: 0.8979 - val_loss: 0.2780 - val_accuracy: 0.8844
# Epoch 54/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2365 - accuracy: 0.8998 - val_loss: 0.2758 - val_accuracy: 0.8836
# Epoch 55/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2423 - accuracy: 0.8977 - val_loss: 0.2692 - val_accuracy: 0.8839
# Epoch 56/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2399 - accuracy: 0.8988 - val_loss: 0.2653 - val_accuracy: 0.8864
# Epoch 57/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2347 - accuracy: 0.9003 - val_loss: 0.2675 - val_accuracy: 0.8880
# Epoch 58/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2346 - accuracy: 0.9007 - val_loss: 0.2699 - val_accuracy: 0.8885
# Epoch 59/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2299 - accuracy: 0.9031 - val_loss: 0.2697 - val_accuracy: 0.8852
# Epoch 60/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2302 - accuracy: 0.9034 - val_loss: 0.2688 - val_accuracy: 0.8846
# Epoch 61/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2287 - accuracy: 0.9032 - val_loss: 0.2736 - val_accuracy: 0.8828
# Epoch 62/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2343 - accuracy: 0.8998 - val_loss: 0.2657 - val_accuracy: 0.8929
# Epoch 63/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2273 - accuracy: 0.9051 - val_loss: 0.2648 - val_accuracy: 0.8887
# Epoch 64/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2290 - accuracy: 0.9034 - val_loss: 0.2708 - val_accuracy: 0.8861
# Epoch 65/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2257 - accuracy: 0.9052 - val_loss: 0.2583 - val_accuracy: 0.8934
# Epoch 66/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2237 - accuracy: 0.9046 - val_loss: 0.2748 - val_accuracy: 0.8849
# Epoch 67/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2298 - accuracy: 0.9038 - val_loss: 0.2731 - val_accuracy: 0.8872
# Epoch 68/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2224 - accuracy: 0.9086 - val_loss: 0.2863 - val_accuracy: 0.8797
# Epoch 69/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2233 - accuracy: 0.9056 - val_loss: 0.2645 - val_accuracy: 0.8893
# Epoch 70/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2256 - accuracy: 0.9060 - val_loss: 0.2607 - val_accuracy: 0.8918
# Epoch 71/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2200 - accuracy: 0.9086 - val_loss: 0.2631 - val_accuracy: 0.8906
# Epoch 72/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2207 - accuracy: 0.9082 - val_loss: 0.2629 - val_accuracy: 0.8887
# Epoch 73/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2179 - accuracy: 0.9095 - val_loss: 0.2579 - val_accuracy: 0.8928
# Epoch 74/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2176 - accuracy: 0.9087 - val_loss: 0.2632 - val_accuracy: 0.8908
# Epoch 75/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2177 - accuracy: 0.9098 - val_loss: 0.2509 - val_accuracy: 0.8975
# Epoch 76/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2173 - accuracy: 0.9095 - val_loss: 0.2568 - val_accuracy: 0.8941
# Epoch 77/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2165 - accuracy: 0.9082 - val_loss: 0.2630 - val_accuracy: 0.8929
# Epoch 78/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2131 - accuracy: 0.9119 - val_loss: 0.2546 - val_accuracy: 0.8947
# Epoch 79/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2144 - accuracy: 0.9095 - val_loss: 0.2706 - val_accuracy: 0.8895
# Epoch 80/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2106 - accuracy: 0.9125 - val_loss: 0.2583 - val_accuracy: 0.8926
# Epoch 81/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2119 - accuracy: 0.9092 - val_loss: 0.2712 - val_accuracy: 0.8897
# Epoch 82/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2136 - accuracy: 0.9113 - val_loss: 0.2549 - val_accuracy: 0.8965
# Epoch 83/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2123 - accuracy: 0.9112 - val_loss: 0.2728 - val_accuracy: 0.8898
# Epoch 84/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2087 - accuracy: 0.9137 - val_loss: 0.2699 - val_accuracy: 0.8910
# Epoch 85/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2094 - accuracy: 0.9134 - val_loss: 0.2623 - val_accuracy: 0.8944
# Epoch 86/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2154 - accuracy: 0.9119 - val_loss: 0.2836 - val_accuracy: 0.8847
# Epoch 87/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2124 - accuracy: 0.9118 - val_loss: 0.2615 - val_accuracy: 0.8918
# Epoch 88/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2040 - accuracy: 0.9144 - val_loss: 0.2833 - val_accuracy: 0.8877
# Epoch 89/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2041 - accuracy: 0.9162 - val_loss: 0.2547 - val_accuracy: 0.8942
# Epoch 90/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2058 - accuracy: 0.9157 - val_loss: 0.2813 - val_accuracy: 0.8846
# Epoch 91/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2034 - accuracy: 0.9139 - val_loss: 0.2705 - val_accuracy: 0.8861
# Epoch 92/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2011 - accuracy: 0.9173 - val_loss: 0.2620 - val_accuracy: 0.8919
# Epoch 93/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2033 - accuracy: 0.9154 - val_loss: 0.2688 - val_accuracy: 0.8890
# Epoch 94/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1995 - accuracy: 0.9169 - val_loss: 0.2581 - val_accuracy: 0.8934
# Epoch 95/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1982 - accuracy: 0.9192 - val_loss: 0.2598 - val_accuracy: 0.8933
# Epoch 96/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1997 - accuracy: 0.9173 - val_loss: 0.2554 - val_accuracy: 0.8952
# Epoch 97/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2015 - accuracy: 0.9157 - val_loss: 0.2757 - val_accuracy: 0.8913
# Epoch 98/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1989 - accuracy: 0.9178 - val_loss: 0.2451 - val_accuracy: 0.9009
# Epoch 99/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1964 - accuracy: 0.9196 - val_loss: 0.2581 - val_accuracy: 0.8916
# Epoch 100/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1965 - accuracy: 0.9183 - val_loss: 0.2470 - val_accuracy: 0.8993
# Epoch 101/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1979 - accuracy: 0.9183 - val_loss: 0.2504 - val_accuracy: 0.9006
# Epoch 102/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1946 - accuracy: 0.9188 - val_loss: 0.2480 - val_accuracy: 0.9001
# Epoch 103/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1924 - accuracy: 0.9199 - val_loss: 0.2516 - val_accuracy: 0.8964
# Epoch 104/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1966 - accuracy: 0.9176 - val_loss: 0.2546 - val_accuracy: 0.8951
# Epoch 105/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1938 - accuracy: 0.9181 - val_loss: 0.2633 - val_accuracy: 0.8928
# Epoch 106/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1926 - accuracy: 0.9210 - val_loss: 0.2483 - val_accuracy: 0.9011
# Epoch 107/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1931 - accuracy: 0.9189 - val_loss: 0.2526 - val_accuracy: 0.8993
# Epoch 108/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1955 - accuracy: 0.9189 - val_loss: 0.2536 - val_accuracy: 0.9009
# Epoch 109/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1953 - accuracy: 0.9185 - val_loss: 0.3032 - val_accuracy: 0.8815
# Epoch 110/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1894 - accuracy: 0.9217 - val_loss: 0.2578 - val_accuracy: 0.8977
# Epoch 111/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1903 - accuracy: 0.9214 - val_loss: 0.2677 - val_accuracy: 0.8933
# Epoch 112/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1927 - accuracy: 0.9183 - val_loss: 0.2626 - val_accuracy: 0.8964
# Epoch 113/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1906 - accuracy: 0.9211 - val_loss: 0.2578 - val_accuracy: 0.8970
# Epoch 114/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1903 - accuracy: 0.9210 - val_loss: 0.2562 - val_accuracy: 0.8987
# Epoch 115/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1875 - accuracy: 0.9222 - val_loss: 0.2593 - val_accuracy: 0.8982
# Epoch 116/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1850 - accuracy: 0.9216 - val_loss: 0.2587 - val_accuracy: 0.8972
# Epoch 117/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1843 - accuracy: 0.9238 - val_loss: 0.2737 - val_accuracy: 0.8888
# Epoch 118/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1864 - accuracy: 0.9228 - val_loss: 0.2603 - val_accuracy: 0.9024
# Epoch 119/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1896 - accuracy: 0.9228 - val_loss: 0.2540 - val_accuracy: 0.9003
# Epoch 120/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1874 - accuracy: 0.9230 - val_loss: 0.2622 - val_accuracy: 0.8978
# Epoch 121/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1915 - accuracy: 0.9213 - val_loss: 0.2713 - val_accuracy: 0.8949
# Epoch 122/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1834 - accuracy: 0.9246 - val_loss: 0.2434 - val_accuracy: 0.9016
# Epoch 123/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1896 - accuracy: 0.9239 - val_loss: 0.2818 - val_accuracy: 0.8916
# Epoch 124/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1830 - accuracy: 0.9242 - val_loss: 0.2526 - val_accuracy: 0.8985
# Epoch 125/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1877 - accuracy: 0.9207 - val_loss: 0.2527 - val_accuracy: 0.8980
# Epoch 126/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1816 - accuracy: 0.9248 - val_loss: 0.2470 - val_accuracy: 0.9028
# Epoch 127/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1757 - accuracy: 0.9282 - val_loss: 0.2536 - val_accuracy: 0.9013
# Epoch 128/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1794 - accuracy: 0.9252 - val_loss: 0.2454 - val_accuracy: 0.9049
# Epoch 129/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1851 - accuracy: 0.9239 - val_loss: 0.2577 - val_accuracy: 0.8995
# Epoch 130/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1785 - accuracy: 0.9250 - val_loss: 0.2631 - val_accuracy: 0.8965
# Epoch 131/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1784 - accuracy: 0.9265 - val_loss: 0.2582 - val_accuracy: 0.8978
# Epoch 132/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1783 - accuracy: 0.9263 - val_loss: 0.2746 - val_accuracy: 0.8965
# Epoch 133/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1785 - accuracy: 0.9247 - val_loss: 0.2618 - val_accuracy: 0.9008
# Epoch 134/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1764 - accuracy: 0.9263 - val_loss: 0.2555 - val_accuracy: 0.9014
# Epoch 135/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1791 - accuracy: 0.9255 - val_loss: 0.2496 - val_accuracy: 0.9028
# Epoch 136/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1780 - accuracy: 0.9261 - val_loss: 0.2465 - val_accuracy: 0.9090
# Epoch 137/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1731 - accuracy: 0.9297 - val_loss: 0.2474 - val_accuracy: 0.9067
# Epoch 138/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1742 - accuracy: 0.9291 - val_loss: 0.2580 - val_accuracy: 0.8991
# Epoch 139/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1787 - accuracy: 0.9261 - val_loss: 0.2640 - val_accuracy: 0.8946
# Epoch 140/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1774 - accuracy: 0.9273 - val_loss: 0.2505 - val_accuracy: 0.9021
# Epoch 141/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.1780 - accuracy: 0.9262 - val_loss: 0.2635 - val_accuracy: 0.8975
# Epoch 142/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1784 - accuracy: 0.9259 - val_loss: 0.2569 - val_accuracy: 0.9037
# Epoch 143/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1727 - accuracy: 0.9285 - val_loss: 0.2755 - val_accuracy: 0.8987
# Epoch 144/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1748 - accuracy: 0.9284 - val_loss: 0.2714 - val_accuracy: 0.8964
# Epoch 145/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1782 - accuracy: 0.9271 - val_loss: 0.2499 - val_accuracy: 0.9034
# Epoch 146/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1757 - accuracy: 0.9292 - val_loss: 0.2728 - val_accuracy: 0.8954
# Epoch 147/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1770 - accuracy: 0.9296 - val_loss: 0.2506 - val_accuracy: 0.9052
# Epoch 148/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1704 - accuracy: 0.9301 - val_loss: 0.2479 - val_accuracy: 0.9049
# Epoch 149/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1768 - accuracy: 0.9256 - val_loss: 0.2550 - val_accuracy: 0.9014
# Epoch 150/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.1680 - accuracy: 0.9319 - val_loss: 0.2746 - val_accuracy: 0.8975

# %%
# Evaluating the model on test data
test_loss_4, test_accuracy_4 = model.evaluate(x_test_reshaped, y_test_encoded, verbose=0)
print('Test Loss:', test_loss_4)
print('Test Accuracy:', test_accuracy_4)
# Saving the model to a file
model.save('RNN.h5')
# Out:
# Test Loss: 0.27455103397369385
# Test Accuracy: 0.8975114822387695

# %%
# Architecture 3: 32-265-3 RNN with 'sigmoid', 'tanh and 'softmax'
# Defining the RNN architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.SimpleRNN(32, activation='relu', input_shape=(input_dimension, 1)))
model.add(tf.keras.layers.Dense(256, activation='tanh'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

# Model Compilation
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Stopping early to avoid overfitting
stop_callback = myCallback()
# Training
history = model.fit(x_train_reshaped, y_train_encoded, epochs=epochs, batch_size=batch_size, validation_data=(x_test_reshaped, y_test_encoded), callbacks=[stop_callback])

# Plotting training and testing curves
default_size = plt.rcParams['figure.figsize']
fig = plt.figure(figsize=[default_size[0] * 2, default_size[1]])

fig.add_subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'accuracy')          # Train accuracy (blue)
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')  # Valid accuracy (orange)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend(loc='lower right')

fig.add_subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')          # Train loss (blue)
plt.plot(history.history['val_loss'], label='val_loss')  # Valid loss (orange)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/150
# 382/382 [==============================] - 3s 6ms/step - loss: 0.5914 - accuracy: 0.7308 - val_loss: 0.4711 - val_accuracy: 0.8003
# Epoch 2/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.4334 - accuracy: 0.8052 - val_loss: 0.4268 - val_accuracy: 0.8065
# Epoch 3/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.4081 - accuracy: 0.8174 - val_loss: 0.3991 - val_accuracy: 0.8173
# Epoch 4/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3942 - accuracy: 0.8235 - val_loss: 0.4051 - val_accuracy: 0.8209
# Epoch 5/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3866 - accuracy: 0.8271 - val_loss: 0.3904 - val_accuracy: 0.8301
# Epoch 6/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3751 - accuracy: 0.8331 - val_loss: 0.4020 - val_accuracy: 0.8240
# Epoch 7/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3688 - accuracy: 0.8364 - val_loss: 0.3709 - val_accuracy: 0.8382
# Epoch 8/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3609 - accuracy: 0.8402 - val_loss: 0.4126 - val_accuracy: 0.8215
# Epoch 9/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3542 - accuracy: 0.8444 - val_loss: 0.3480 - val_accuracy: 0.8479
# Epoch 10/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3497 - accuracy: 0.8433 - val_loss: 0.3597 - val_accuracy: 0.8409
# Epoch 11/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3443 - accuracy: 0.8494 - val_loss: 0.4888 - val_accuracy: 0.8066
# Epoch 12/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3412 - accuracy: 0.8490 - val_loss: 0.3355 - val_accuracy: 0.8528
# Epoch 13/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3371 - accuracy: 0.8535 - val_loss: 0.3480 - val_accuracy: 0.8505
# Epoch 14/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3326 - accuracy: 0.8535 - val_loss: 0.3269 - val_accuracy: 0.8631
# Epoch 15/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3291 - accuracy: 0.8554 - val_loss: 0.3348 - val_accuracy: 0.8558
# Epoch 16/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3269 - accuracy: 0.8575 - val_loss: 0.3435 - val_accuracy: 0.8528
# Epoch 17/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3246 - accuracy: 0.8578 - val_loss: 0.3317 - val_accuracy: 0.8567
# Epoch 18/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3206 - accuracy: 0.8589 - val_loss: 0.3309 - val_accuracy: 0.8525
# Epoch 19/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3158 - accuracy: 0.8632 - val_loss: 0.3253 - val_accuracy: 0.8610
# Epoch 20/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3143 - accuracy: 0.8632 - val_loss: 0.3222 - val_accuracy: 0.8621
# Epoch 21/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3115 - accuracy: 0.8637 - val_loss: 0.3469 - val_accuracy: 0.8466
# Epoch 22/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3082 - accuracy: 0.8688 - val_loss: 0.3145 - val_accuracy: 0.8657
# Epoch 23/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3043 - accuracy: 0.8663 - val_loss: 0.3226 - val_accuracy: 0.8608
# Epoch 24/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3037 - accuracy: 0.8676 - val_loss: 0.3413 - val_accuracy: 0.8484
# Epoch 25/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.3022 - accuracy: 0.8672 - val_loss: 0.3229 - val_accuracy: 0.8572
# Epoch 26/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.3005 - accuracy: 0.8704 - val_loss: 0.3185 - val_accuracy: 0.8659
# Epoch 27/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2970 - accuracy: 0.8712 - val_loss: 0.3081 - val_accuracy: 0.8674
# Epoch 28/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2973 - accuracy: 0.8715 - val_loss: 0.3110 - val_accuracy: 0.8636
# Epoch 29/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2928 - accuracy: 0.8740 - val_loss: 0.2990 - val_accuracy: 0.8759
# Epoch 30/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2913 - accuracy: 0.8745 - val_loss: 0.3089 - val_accuracy: 0.8659
# Epoch 31/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2904 - accuracy: 0.8751 - val_loss: 0.3078 - val_accuracy: 0.8679
# Epoch 32/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2887 - accuracy: 0.8760 - val_loss: 0.3064 - val_accuracy: 0.8715
# Epoch 33/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2873 - accuracy: 0.8761 - val_loss: 0.2984 - val_accuracy: 0.8744
# Epoch 34/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2855 - accuracy: 0.8757 - val_loss: 0.3034 - val_accuracy: 0.8756
# Epoch 35/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2849 - accuracy: 0.8782 - val_loss: 0.3299 - val_accuracy: 0.8574
# Epoch 36/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2847 - accuracy: 0.8776 - val_loss: 0.2984 - val_accuracy: 0.8723
# Epoch 37/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2831 - accuracy: 0.8773 - val_loss: 0.3214 - val_accuracy: 0.8666
# Epoch 38/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2822 - accuracy: 0.8787 - val_loss: 0.2934 - val_accuracy: 0.8792
# Epoch 39/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2814 - accuracy: 0.8806 - val_loss: 0.2932 - val_accuracy: 0.8748
# Epoch 40/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2792 - accuracy: 0.8824 - val_loss: 0.2983 - val_accuracy: 0.8741
# Epoch 41/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2775 - accuracy: 0.8812 - val_loss: 0.3171 - val_accuracy: 0.8692
# Epoch 42/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2788 - accuracy: 0.8794 - val_loss: 0.2985 - val_accuracy: 0.8739
# Epoch 43/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2775 - accuracy: 0.8821 - val_loss: 0.3091 - val_accuracy: 0.8746
# Epoch 44/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2775 - accuracy: 0.8810 - val_loss: 0.3000 - val_accuracy: 0.8715
# Epoch 45/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2753 - accuracy: 0.8836 - val_loss: 0.2966 - val_accuracy: 0.8761
# Epoch 46/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2750 - accuracy: 0.8841 - val_loss: 0.2992 - val_accuracy: 0.8743
# Epoch 47/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2734 - accuracy: 0.8819 - val_loss: 0.3202 - val_accuracy: 0.8661
# Epoch 48/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2728 - accuracy: 0.8843 - val_loss: 0.2975 - val_accuracy: 0.8769
# Epoch 49/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2706 - accuracy: 0.8839 - val_loss: 0.2961 - val_accuracy: 0.8792
# Epoch 50/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2721 - accuracy: 0.8827 - val_loss: 0.2998 - val_accuracy: 0.8698
# Epoch 51/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2722 - accuracy: 0.8827 - val_loss: 0.2994 - val_accuracy: 0.8738
# Epoch 52/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2694 - accuracy: 0.8843 - val_loss: 0.3002 - val_accuracy: 0.8720
# Epoch 53/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2690 - accuracy: 0.8837 - val_loss: 0.3092 - val_accuracy: 0.8730
# Epoch 54/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2696 - accuracy: 0.8846 - val_loss: 0.3152 - val_accuracy: 0.8731
# Epoch 55/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2686 - accuracy: 0.8849 - val_loss: 0.2968 - val_accuracy: 0.8779
# Epoch 56/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2661 - accuracy: 0.8873 - val_loss: 0.3053 - val_accuracy: 0.8748
# Epoch 57/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2668 - accuracy: 0.8873 - val_loss: 0.2934 - val_accuracy: 0.8772
# Epoch 58/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2645 - accuracy: 0.8890 - val_loss: 0.3088 - val_accuracy: 0.8728
# Epoch 59/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2648 - accuracy: 0.8869 - val_loss: 0.2996 - val_accuracy: 0.8733
# Epoch 60/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2649 - accuracy: 0.8874 - val_loss: 0.2991 - val_accuracy: 0.8762
# Epoch 61/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2643 - accuracy: 0.8860 - val_loss: 0.2979 - val_accuracy: 0.8779
# Epoch 62/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2638 - accuracy: 0.8876 - val_loss: 0.2987 - val_accuracy: 0.8759
# Epoch 63/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2614 - accuracy: 0.8870 - val_loss: 0.2924 - val_accuracy: 0.8803
# Epoch 64/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2618 - accuracy: 0.8891 - val_loss: 0.2936 - val_accuracy: 0.8803
# Epoch 65/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2611 - accuracy: 0.8901 - val_loss: 0.3090 - val_accuracy: 0.8767
# Epoch 66/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2618 - accuracy: 0.8877 - val_loss: 0.2984 - val_accuracy: 0.8741
# Epoch 67/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2600 - accuracy: 0.8885 - val_loss: 0.2952 - val_accuracy: 0.8806
# Epoch 68/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2591 - accuracy: 0.8907 - val_loss: 0.3111 - val_accuracy: 0.8744
# Epoch 69/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2589 - accuracy: 0.8895 - val_loss: 0.3025 - val_accuracy: 0.8736
# Epoch 70/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2586 - accuracy: 0.8908 - val_loss: 0.3032 - val_accuracy: 0.8784
# Epoch 71/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2569 - accuracy: 0.8910 - val_loss: 0.2957 - val_accuracy: 0.8784
# Epoch 72/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2580 - accuracy: 0.8898 - val_loss: 0.2999 - val_accuracy: 0.8744
# Epoch 73/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2573 - accuracy: 0.8912 - val_loss: 0.2995 - val_accuracy: 0.8790
# Epoch 74/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2575 - accuracy: 0.8915 - val_loss: 0.3099 - val_accuracy: 0.8716
# Epoch 75/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2549 - accuracy: 0.8935 - val_loss: 0.2912 - val_accuracy: 0.8826
# Epoch 76/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2561 - accuracy: 0.8912 - val_loss: 0.2881 - val_accuracy: 0.8843
# Epoch 77/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2535 - accuracy: 0.8928 - val_loss: 0.3113 - val_accuracy: 0.8749
# Epoch 78/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2564 - accuracy: 0.8918 - val_loss: 0.2958 - val_accuracy: 0.8752
# Epoch 79/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2543 - accuracy: 0.8934 - val_loss: 0.2869 - val_accuracy: 0.8824
# Epoch 80/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2552 - accuracy: 0.8918 - val_loss: 0.2808 - val_accuracy: 0.8826
# Epoch 81/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2536 - accuracy: 0.8921 - val_loss: 0.3094 - val_accuracy: 0.8744
# Epoch 82/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2544 - accuracy: 0.8924 - val_loss: 0.3012 - val_accuracy: 0.8772
# Epoch 83/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2538 - accuracy: 0.8923 - val_loss: 0.2907 - val_accuracy: 0.8821
# Epoch 84/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2524 - accuracy: 0.8934 - val_loss: 0.2965 - val_accuracy: 0.8805
# Epoch 85/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2524 - accuracy: 0.8930 - val_loss: 0.2864 - val_accuracy: 0.8800
# Epoch 86/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2516 - accuracy: 0.8918 - val_loss: 0.2936 - val_accuracy: 0.8761
# Epoch 87/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2521 - accuracy: 0.8943 - val_loss: 0.3063 - val_accuracy: 0.8748
# Epoch 88/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2505 - accuracy: 0.8952 - val_loss: 0.2996 - val_accuracy: 0.8820
# Epoch 89/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2519 - accuracy: 0.8933 - val_loss: 0.2863 - val_accuracy: 0.8820
# Epoch 90/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2493 - accuracy: 0.8968 - val_loss: 0.3060 - val_accuracy: 0.8751
# Epoch 91/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2504 - accuracy: 0.8927 - val_loss: 0.2858 - val_accuracy: 0.8820
# Epoch 92/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2529 - accuracy: 0.8929 - val_loss: 0.2847 - val_accuracy: 0.8854
# Epoch 93/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2504 - accuracy: 0.8959 - val_loss: 0.3019 - val_accuracy: 0.8784
# Epoch 94/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2504 - accuracy: 0.8940 - val_loss: 0.2986 - val_accuracy: 0.8751
# Epoch 95/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2487 - accuracy: 0.8955 - val_loss: 0.2895 - val_accuracy: 0.8784
# Epoch 96/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2509 - accuracy: 0.8943 - val_loss: 0.2840 - val_accuracy: 0.8824
# Epoch 97/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2496 - accuracy: 0.8957 - val_loss: 0.2761 - val_accuracy: 0.8898
# Epoch 98/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2490 - accuracy: 0.8937 - val_loss: 0.2938 - val_accuracy: 0.8803
# Epoch 99/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2480 - accuracy: 0.8946 - val_loss: 0.2765 - val_accuracy: 0.8880
# Epoch 100/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2476 - accuracy: 0.8954 - val_loss: 0.2839 - val_accuracy: 0.8843
# Epoch 101/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2486 - accuracy: 0.8960 - val_loss: 0.2907 - val_accuracy: 0.8780
# Epoch 102/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2496 - accuracy: 0.8949 - val_loss: 0.3238 - val_accuracy: 0.8723
# Epoch 103/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2486 - accuracy: 0.8949 - val_loss: 0.2796 - val_accuracy: 0.8810
# Epoch 104/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2476 - accuracy: 0.8962 - val_loss: 0.2792 - val_accuracy: 0.8834
# Epoch 105/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2471 - accuracy: 0.8949 - val_loss: 0.3020 - val_accuracy: 0.8784
# Epoch 106/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2470 - accuracy: 0.8968 - val_loss: 0.2891 - val_accuracy: 0.8816
# Epoch 107/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2467 - accuracy: 0.8969 - val_loss: 0.3050 - val_accuracy: 0.8780
# Epoch 108/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2466 - accuracy: 0.8959 - val_loss: 0.2915 - val_accuracy: 0.8797
# Epoch 109/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2447 - accuracy: 0.8966 - val_loss: 0.2907 - val_accuracy: 0.8787
# Epoch 110/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2454 - accuracy: 0.8961 - val_loss: 0.2955 - val_accuracy: 0.8816
# Epoch 111/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2460 - accuracy: 0.8968 - val_loss: 0.2893 - val_accuracy: 0.8838
# Epoch 112/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2448 - accuracy: 0.8979 - val_loss: 0.2983 - val_accuracy: 0.8820
# Epoch 113/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2455 - accuracy: 0.8969 - val_loss: 0.2966 - val_accuracy: 0.8810
# Epoch 114/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2448 - accuracy: 0.8978 - val_loss: 0.2975 - val_accuracy: 0.8826
# Epoch 115/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2454 - accuracy: 0.8970 - val_loss: 0.2820 - val_accuracy: 0.8843
# Epoch 116/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2431 - accuracy: 0.8979 - val_loss: 0.2987 - val_accuracy: 0.8792
# Epoch 117/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2444 - accuracy: 0.8984 - val_loss: 0.3184 - val_accuracy: 0.8741
# Epoch 118/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2415 - accuracy: 0.8966 - val_loss: 0.2923 - val_accuracy: 0.8815
# Epoch 119/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2428 - accuracy: 0.8995 - val_loss: 0.2903 - val_accuracy: 0.8770
# Epoch 120/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2421 - accuracy: 0.8974 - val_loss: 0.2783 - val_accuracy: 0.8887
# Epoch 121/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2425 - accuracy: 0.8983 - val_loss: 0.3105 - val_accuracy: 0.8790
# Epoch 122/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2425 - accuracy: 0.8992 - val_loss: 0.3175 - val_accuracy: 0.8759
# Epoch 123/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2410 - accuracy: 0.8990 - val_loss: 0.3105 - val_accuracy: 0.8770
# Epoch 124/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2420 - accuracy: 0.8991 - val_loss: 0.2749 - val_accuracy: 0.8906
# Epoch 125/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2440 - accuracy: 0.8980 - val_loss: 0.2950 - val_accuracy: 0.8775
# Epoch 126/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2409 - accuracy: 0.8975 - val_loss: 0.2816 - val_accuracy: 0.8834
# Epoch 127/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2391 - accuracy: 0.8993 - val_loss: 0.2936 - val_accuracy: 0.8793
# Epoch 128/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2402 - accuracy: 0.8993 - val_loss: 0.2791 - val_accuracy: 0.8861
# Epoch 129/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2402 - accuracy: 0.8998 - val_loss: 0.3036 - val_accuracy: 0.8772
# Epoch 130/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2399 - accuracy: 0.8998 - val_loss: 0.2933 - val_accuracy: 0.8779
# Epoch 131/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2402 - accuracy: 0.8993 - val_loss: 0.2887 - val_accuracy: 0.8838
# Epoch 132/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2411 - accuracy: 0.9004 - val_loss: 0.2839 - val_accuracy: 0.8854
# Epoch 133/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2396 - accuracy: 0.8992 - val_loss: 0.2895 - val_accuracy: 0.8834
# Epoch 134/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2384 - accuracy: 0.8981 - val_loss: 0.2877 - val_accuracy: 0.8861
# Epoch 135/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2401 - accuracy: 0.8993 - val_loss: 0.2896 - val_accuracy: 0.8847
# Epoch 136/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2398 - accuracy: 0.8996 - val_loss: 0.2878 - val_accuracy: 0.8838
# Epoch 137/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2401 - accuracy: 0.8994 - val_loss: 0.2935 - val_accuracy: 0.8813
# Epoch 138/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2411 - accuracy: 0.8984 - val_loss: 0.2960 - val_accuracy: 0.8820
# Epoch 139/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2384 - accuracy: 0.8997 - val_loss: 0.2844 - val_accuracy: 0.8857
# Epoch 140/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2379 - accuracy: 0.8988 - val_loss: 0.2964 - val_accuracy: 0.8800
# Epoch 141/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2387 - accuracy: 0.8995 - val_loss: 0.2734 - val_accuracy: 0.8865
# Epoch 142/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2380 - accuracy: 0.8996 - val_loss: 0.2824 - val_accuracy: 0.8852
# Epoch 143/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2367 - accuracy: 0.9006 - val_loss: 0.2876 - val_accuracy: 0.8847
# Epoch 144/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2388 - accuracy: 0.9006 - val_loss: 0.3025 - val_accuracy: 0.8762
# Epoch 145/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2368 - accuracy: 0.9014 - val_loss: 0.2804 - val_accuracy: 0.8865
# Epoch 146/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2389 - accuracy: 0.9029 - val_loss: 0.3306 - val_accuracy: 0.8694
# Epoch 147/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2352 - accuracy: 0.9021 - val_loss: 0.2835 - val_accuracy: 0.8852
# Epoch 148/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2362 - accuracy: 0.9019 - val_loss: 0.2988 - val_accuracy: 0.8785
# Epoch 149/150
# 382/382 [==============================] - 2s 6ms/step - loss: 0.2357 - accuracy: 0.9007 - val_loss: 0.2872 - val_accuracy: 0.8838
# Epoch 150/150
# 382/382 [==============================] - 2s 5ms/step - loss: 0.2352 - accuracy: 0.9000 - val_loss: 0.2993 - val_accuracy: 0.8784

# %%
# Evaluating the model on test data
test_loss_5, test_accuracy_5 = model.evaluate(x_test_reshaped, y_test_encoded, verbose=0)
print('Test Loss:', test_loss_5)
print('Test Accuracy:', test_accuracy_5)
# Out:
# Test Loss: 0.29927152395248413
# Test Accuracy: 0.8783562779426575

# %%
# Results
print("Testing Performances for Deep Learning Algorithms on 150 Epochs")
result = pd.DataFrame({"Algorithms":['64-64-128-3 Feed Forward Neural Network', "32-256-3 Feed Forward Neural Network", "32-256-3 Feed Forward Neural Network", "32-64-128-3 Recurrent Neural Network", "32-256-3 Recurrent Neural Network", "32-256-3 Recurrent Neural Network"],
                       "Activation Functions":["relu", "relu","sigmoid", "relu","relu", "relu & tanh"],
                       "Optimizers":["Adam","SGD","SGD","Adam","Adam", "RMSprop"],
                       "Accuracy":[round(test_accuracy_0,3), round(test_accuracy_1,3), round(test_accuracy_2,3), round(test_accuracy_3,3), round(test_accuracy_4,3), round(test_accuracy_5,3)],
                       "Loss":[round(test_loss_0,3), round(test_loss_1,3), round(test_loss_2,3), round(test_loss_3,3), round(test_loss_4,3), round(test_loss_5,3)]}).set_index('Algorithms')
result
# Out:
# Testing Performances for Deep Learning Algorithms on 150 Epochs
#                                         Activation Functions Optimizers  \
# Algorithms
# 64-64-128-3 Feed Forward Neural Network                 relu       Adam
# 32-256-3 Feed Forward Neural Network                    relu        SGD
# 32-256-3 Feed Forward Neural Network                 sigmoid        SGD
# 32-64-128-3 Recurrent Neural Network                    relu       Adam
# 32-256-3 Recurrent Neural Network                       relu       Adam
# 32-256-3 Recurrent Neural Network                relu & tanh    RMSprop
#
#                                          Accuracy   Loss
# Algorithms
# 64-64-128-3 Feed Forward Neural Network     0.909  0.259
# 32-256-3 Feed Forward Neural Network        0.838  0.381
# 32-256-3 Feed Forward Neural Network        0.771  0.592
# 32-64-128-3 Recurrent Neural Network        0.902  0.290
# 32-256-3 Recurrent Neural Network           0.898  0.275
# 32-256-3 Recurrent Neural Network           0.878  0.299
